# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritu04/Python/blob/main/whileloop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Write a Python program to print the sum of all even numbers between 1 and 100 using a while loop Output:
# Sum of even numbers = 2550

# %%
i = 1
total = 0

while i <= 100:
    if i % 2 == 0:
        total += i
    i += 1

print("Sum of even numbers =", total)
# Out:
# Sum of even numbers = 2550

# %% [markdown]
# Q2: Write a Python program to reverse a number using a while loop.
# Example:
# Input: 1234
# Output: 4321

# %%
n = int(input("Enter a number: "))
rev = 0

while n > 0:
    digit = n % 10
    rev = rev * 10 + digit
    n //= 10

print("Reversed number:", rev)
# Out:
# Enter a number: 1234
# Reversed number: 4321

# %% [markdown]
# Q3: Write a Python program to find the sum of digits of a given number using a while loop.
# Example:
# Input: 567
# Output: 18 (5 + 6 + 7 = 18)

# %%
n= int(input("Enter a number: "))
sum = 0

while n > 0:
    digit = n % 10
    sum += digit
    n //= 10

print("Sum of digits =", sum)
# Out:
# Enter a number: 567
# Sum of digits = 18

# %% [markdown]
# Q4: Write a Python program to find the greatest common divisor (GCD) of two numbers using a while loop.
# Example:
# Input: 36, 60
# Output: 12

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

while num2 != 0:
    num1, num2 = num2, num1 % num2

print("GCD =", num1)
# Out:
# Enter first number: 36
# Enter second number: 60
# GCD = 12

# %% [markdown]
# Q5: Write a Python program to calculate the power of a number using a while loop (without using the ** operator).
# Example:
# Input: base = 2, exponent = 4
# Output: 16 (because 2^4 = 16)

# %%
base = int(input("Enter base: "))
exp = int(input("Enter exponent: "))

power = 1
i = 1

while i <= exp:
    power *= base
    i += 1

print("Power =", power)
# Out:
# Enter base: 2
# Enter exponent: 4
# Power = 16

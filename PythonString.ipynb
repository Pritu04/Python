# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritu04/Python/blob/main/PythonString.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1 Write a Python program that accepts a string from user. Your program should create and display a new string where the first and last characters have been exchanged.
#
# For example if the user enters the string 'HELLO' then new string would be 'OELLH'

# %%
string= input("Enter a String =")
first = string[0]
last= string[-1]
mid = string [1 : -1]
print(last + mid + first)
# Out:
# Enter a String =AbhisheK
# KbhisheA

# %% [markdown]
# Q2 Write a Python program that accepts a string from user. Your program should create a new string in reverse of first string and display it.
#
# For example if the user enters the string 'EXAM' then new string would be 'MAXE'

# %%
my_string=input("Enter String =")
reversed_string=my_string[::-1]
print(reversed_string)
# Out:
# Enter String =shubham
# mahbuhs

# %% [markdown]
# Q3 Write a Python program that accepts a string from user. Your program should create a new string by shifting one position to left.
#
# For example if the user enters the string 'examination 2021' then new string would be 'xamination 2021e'

# %%
string= input("Enter a String =")
first = string[1: ]
last= string[0]
print(first+last)
# Out:
# Enter a String =examination 2025
# xamination 2025e

# %% [markdown]
# Q4 Write a Python program to calculate the length of a string.

# %%
string= input("Enter a String =")
length_of_string = len(string)
print("length of string=",length_of_string)
# Out:
# Enter a String =sandy
# length of string= 5

# %% [markdown]
# Q5 Write a Python program to get a string made of the first 2 and last 2 characters of a given string. If the string length is less than 2, return the empty string instead.
# Sample String : 'w3resource'
# Expected Result : 'w3ce'
# Sample String : 'w3'
# Expected Result : 'w3w3'
# Sample String : ' w'
# Expected Result : Empty String

# %%
string=input("enter string =")
first=string[:2]
last=string[-2:]
if len(string) < 2:
 print("empty")
else:
   print(first+last)
# Out:
# enter string =shubham
# sham

# %% [markdown]
# Q6 Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing', add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.
# Sample String : 'abc'
# Expected Result : 'abcing'
# Sample String : 'string'
# Expected Result : 'stringly'

# %%
string = input()
length = len(string)

if length >= 3:
    if string.endswith('ing'):
        print(string + 'ly')
    else:
        print(string + 'ing')
else:
    print(string)
# Out:
# going
# goingly

# %% [markdown]
# Q7 Write a Python program to remove the nth index character from a nonempty string.

# %%
string = input("Enter a string: ")
try:
    n = int(input("Enter the index of the character to remove: "))
except ValueError:
    print("Invalid input: Please enter an integer for the index.")
else:
    if n < len(string) and n >= 0:
        new_string = string[:n] + string[n+1:]
        print("String after removing character: ", new_string)
    else:
        print("Index out of range.")
# Out:
# Enter a string: raj yadav
# Enter the index of the character to remove: ajy
# Invalid input: Please enter an integer for the index.

# %% [markdown]
# Q8 Write a Python program to change a given string to a newly string where the first and last chars have been exchanged.

# %%
string = input("Enter a String: ")
if len(string) > 1:
    first = string[0]
    last = string[-1]
    mid = string[1:-1]
    print(last + mid + first)
else:
    print(string) # If string has 0 or 1 character, return as is
# Out:
# Enter a String: sai
# ias

# %% [markdown]
# Q9 Write a Python script that takes input from the user and displays that in upper and lower cases.

# %%
user_string = input("Enter a string: ")
print("Uppercase:", user_string.upper())
print("Lowercase:", user_string.lower())
# Out:
# Enter a string: shubham supanekar
# Uppercase: SHUBHAM SUPANEKAR
# Lowercase: shubham supanekar

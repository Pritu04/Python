# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritu04/Python/blob/main/Copy_of_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1- Write a program to access the third element from the given list.
# Input: [10, 20, 30, 40, 50]
# Output: 30

# %%
a = [10, 20, 30, 40, 50]
print(a[2])    # output
print(a[-2])
# Out:
# 30
# 40

# %% [markdown]
# 2 Write a program to access the last element from the given list using negative indexing.
# Input: ['apple', 'banana', 'cherry', 'date']
# Output: date

# %%
a = ['apple', 'banana', 'cherry', 'date']
print(a[-1])   # output
print(a[3])
# Out:
# date
# date

# %% [markdown]
# 3 Write a program to change the second element to 100 in the given list.
# Input: [5, 10, 15, 20, 25]
# Output: [5, 100, 15, 20, 25]

# %%
a=  [5, 10, 15, 20, 25]
a[1] = 100
print(a)    # oupput
# Out:
# [5, 100, 15, 20, 25]

# %% [markdown]
# 4 Write a program to access the first element using negative indexing.
# Input: [7, 14, 21, 28, 35]
# Output: 7

# %%
a = [7, 14, 21, 28, 35]
__builtins__.print(a[-5])   # output
# The line below is also correct but was failing due to a shadowed 'print' variable.
# print(a[0])
# Out:
# 7

# %% [markdown]
# 5 Write a program to access the second last element from the given list.
# Input: [1, 2, 3, 4, 5, 6]
# Output: 5

# %%
a = [1, 2, 3, 4, 5, 6]
__builtins__.print(a[-2])   # output
# Out:
# 5

# %% [markdown]
# Slicing Questions
#
#
# 6 Write a program to extract the first three elements from the given list.
# Input: [100, 200, 300, 400, 500, 600]
# Output: [100, 200, 300]

# %%
a = [100, 200, 300, 400, 500, 600]
__builtins__.print(a[:3])   # output
# Out:
# [100, 200, 300]

# %% [markdown]
# 7 Write a program to extract all elements except the first two from the given list.
# Input: [2, 4, 6, 8, 10, 12]
# Output: [6, 8, 10, 12]

# %%
a = [2, 4, 6, 8, 10, 12]
__builtins__.print(a[2:])  # output
__builtins__.print(a[5:])
# Out:
# [6, 8, 10, 12]
# [12]

# %% [markdown]
# 8 Write a program to extract every alternate element from the given list.
# Input: [5, 10, 15, 20, 25, 30, 35]
# Output: [5, 15, 25, 35]

# %%
a = [5, 10, 15, 20, 25, 30, 35]
__builtins__.print(a[::2])    # output
__builtins__.print(a[::3])
# Out:
# [5, 15, 25, 35]
# [5, 20, 35]

# %% [markdown]
# 9 Write a program to reverse the given list using slicing.
# Input: [1, 3, 5, 7, 9]
# Output: [9, 7, 5, 3, 1]

# %%
a = [1, 3, 5, 7, 9]
__builtins__.print(a[::-1])  # output
__builtins__.print(a[::-3])
# Out:
# [9, 7, 5, 3, 1]
# [9, 3]

# %% [markdown]
# 10 Write a program to extract elements from index 2 to 5 from the given list.
# Input: [11, 22, 33, 44, 55, 66, 77]
# Output: [33, 44, 55, 66]

# %%
a = [11, 22, 33, 44, 55, 66, 77]
__builtins__.print(a[2:5])  #output
# Out:
# [33, 44, 55]

# %% [markdown]
# Nested Slicing Questions
#
#
#
# 11 Write a program to access the second element from the first nested list.
# Input: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# Output: 2

# %%
nested_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
__builtins__.print(nested_list[0][1]) # output
# Out:
# 2

# %% [markdown]
# 12 Write a program to extract the last element from the last nested list.
# Input: [['a', 'b', 'c'], ['d', 'e', 'f'], ['g', 'h', 'i']]
# Output: i

# %%
nested_list =  [['a', 'b', 'c'], ['d', 'e', 'f'], ['g', 'h', 'i']]
__builtins__.print(nested_list[-1][-1])    # output
# Out:
# i

# %% [markdown]
# 13 Write a program to extract the second and third lists from a given nested list.
# Input: [[10, 20], [30, 40], [50, 60], [70, 80]]
# Output: [[30, 40], [50, 60]]

# %%
c = [[10, 20], [30, 40], [50, 60], [70, 80]]
__builtins__.print(c[1:3])   # output
# Out:
# [[30, 40], [50, 60]]

# %% [markdown]
# 14 Write a program to extract the second element from all nested lists.
# Input: [[1, 9], [2, 8], [3, 7], [4, 6]]
# Output: [9, 8, 7, 6]

# %%
c =  [[1, 9], [2, 8], [3, 7], [4, 6]]
output = [sublist[1] for sublist in c]
__builtins__.print(output)   # output
# Out:
# [9, 8, 7, 6]

# %% [markdown]
# 15 Write a program to reverse all sublists in a nested list.
# Input: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# Output: [[3, 2, 1], [6, 5, 4], [9, 8, 7]]

# %%
 a =  [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
 __builtins__.print([sublist[::-1] for sublist in a])   # output
# Out:
# [[3, 2, 1], [6, 5, 4], [9, 8, 7]]

# %% [markdown]
# append() Function Questions
#
#
#
# 1- Write a program to append the number 100 to the given list.
# Input: [10, 20, 30, 40]
# Output: [10, 20, 30, 40, 100]

# %%
a = [10, 20, 30, 40]
a.append(100)
__builtins__.print(a) # output
# Out:
# [10, 20, 30, 40, 100]

# %%
c = [10, 20, 30, 40]
a.append(100)
__builtins__.print(c)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# 2 Write a program to append a string "Hello" to the given list.
# Input: ['apple', 'banana', 'cherry']
# Output: ['apple', 'banana', 'cherry', 'Hello']

# %%
c =  ['apple', 'banana', 'cherry']
c.append("Hello")
__builtins__.print(c)
# Out:
# ['apple', 'banana', 'cherry', 'Hello']

# %% [markdown]
# 3 Write a program to append a list [5, 6, 7] as a single element in the given list.
# Input: [1, 2, 3, 4]
# Output: [1, 2, 3, 4, [5, 6, 7]]

# %%
a = [1, 2, 3, 4]
a.append([5, 6, 7])   # output
__builtins__.print(a)
# Out:
# [1, 2, 3, 4, [5, 6, 7]]

# %% [markdown]
# extend() Function Questions
#
#
#
# 4 Write a program to extend the given list by adding another list [50, 60, 70].
# Input: [10, 20, 30, 40]
# Output: [10, 20, 30, 40, 50, 60, 70]

# %%
c =  [10, 20, 30, 40]
c.extend([50, 60, 70])  # output
__builtins__.print(c)
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %% [markdown]
# 5 Write a program to extend a list of numbers [7, 8, 9] with another list [10, 11, 12].
# Input: [7, 8, 9]
# Output: [7, 8, 9, 10, 11, 12]

# %%
c =  [7, 8, 9]
c.extend([10,11,12])   #output
__builtins__.print(c)
# Out:
# [7, 8, 9, 10, 11, 12]

# %% [markdown]
# 6 Write a program to extend a list of strings ["cat", "dog"] with another list ["lion", "tiger"].
# Input: ["cat", "dog"]
# Output: ["cat", "dog", "lion", "tiger"]

# %%
c =  ["cat", "dog"]
c.extend(["lion", "tiger"])  # output
__builtins__.print(c)
# Out:
# ['cat', 'dog', 'lion', 'tiger']

# %% [markdown]
# pop() Function Questions
#
#
#
# 7 Write a program to remove the last element from the given list using the pop function.
# Input: [10, 20, 30, 40]
# Output: [10, 20, 30]

# %%
c =  [10, 20, 30, 40]
c.pop()               # output
__builtins__.print(c)
# Out:
# [10, 20, 30]

# %% [markdown]
# 8 Write a program to remove the third element from the given list using the pop function.
# Input: [1, 2, 3, 4, 5]
# Output: [1, 2, 4, 5]

# %%
c =  [1, 2, 3, 4, 5]
c.pop(2)         #output
__builtins__.print(c)
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# 9 Write a program to remove the first element from the given list using the pop function.
# Input: [100, 200, 300, 400]
# Output: [200, 300, 400]

# %%
c = [100, 200, 300, 400]
c.pop(0)               #  output
__builtins__.print(c)
# Out:
# [200, 300, 400]

# %% [markdown]
# remove() Function Questions
#
#
#
# 10 Write a program to remove the element 20 from the given list.
# Input: [10, 20, 30, 40, 50]
# Output: [10, 30, 40, 50]

# %%
c = [10, 20, 30, 40, 50]
c.remove(20)    # output
__builtins__.print(c)
# Out:
# [10, 30, 40, 50]

# %% [markdown]
# 11 Write a program to remove the first occurrence of "apple" from the given list.
# Input: ["banana", "apple", "cherry", "apple"]
# Output: ["banana", "cherry", "apple"]

# %%
c = ["banana", "apple", "cherry", "apple"]
c.remove("apple")  # output
__builtins__.print(c)
# Out:
# ['banana', 'cherry', 'apple']

# %% [markdown]
# 12 Write a program to remove the number 5 from the given list if it exists.
# Input: [1, 2, 3, 4, 5, 6]
# Output: [1, 2, 3, 4, 6]

# %%
 c = [1, 2, 3, 4, 5, 6]
 c.remove(5)  # output
 __builtins__.print(c)
# Out:
# [1, 2, 3, 4, 6]

# %% [markdown]
# index() Function Questions
#
#
# 13 Write a program to find the index of the element 50 in the given list.
# Input: [10, 20, 30, 40, 50, 60]
# Output: 4

# %%
c = [10, 20, 30, 40, 50, 60]
__builtins__.print(c.index(50))   # output
# Out:
# 4

# %%
c = [10, 20, 30, 40, 50, 60]
__builtins__.print(c.index(50))
# Out:
# 4

# %% [markdown]
# 14 Write a program to find the index of "cherry" in the given list.
# Input: ["apple", "banana", "cherry", "date"]
# Output: 2

# %%
c = ["apple", "banana", "cherry", "date"]
__builtins__.print(c.index("cherry"))  # output
# Out:
# 2

# %%
c = ["apple", "banana", "cherry", "date"]
__builtins__.print(c.index("cherry"))
# Out:
# 2

# %% [markdown]
# 15 Write a program to find the index of the number 100 in the given list. If not found, print "Not found".
# Input: [10, 20, 30, 40]
# Output: "Not found"

# %%
a = [10, 20, 30, 40]
if 100 in a:
  __builtins__.print(a.index(100))     # output
else:
  __builtins__.print("Notfound")
# Out:
# Notfound

# %%
a = [10, 20, 30, 40]
print(a.index(100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3424309840.py in <cell line: 0>()
#       1 a = [10, 20, 30, 40]
# ----> 2 print(a.index(100))
#       3 print("Notfound")
#
# ValueError: 100 is not in list

# %% [markdown]
# count() Function Questions
#
#
#
# 16 Write a program to count the occurrences of 5 in the given list.
# Input: [1, 5, 2, 5, 3, 5, 4]
# Output: 3

# %%
c = [1, 5, 2, 5, 3, 5, 4]
__builtins__.print(c.count(5))  # output
# Out:
# 3

# %% [markdown]
# 17 Write a program to count how many times "apple" appears in the given list.
# Input: ["apple", "banana", "apple", "cherry", "apple"]
# Output: 3

# %%
c = ["apple", "banana", "apple", "cherry", "apple"]
__builtins__.print(c.count("apple"))   # output
# Out:
# 3

# %% [markdown]
# 18 Write a program to count the occurrences of 100 in the given list.
# Input: [10, 20, 30, 40, 50]
# Output: 0

# %%
f =  [10, 20, 30, 40, 50]
__builtins__.print(f.count(100))  # output
# Out:
# 0

# %% [markdown]
# min() and max() Function Questions
#
#
#
# 19 Write a program to find the minimum value in the given list.
# Input: [45, 12, 78, 34, 23]
# Output: 12

# %%
s =  [45, 12, 78, 34, 23]
__builtins__.print(min(s))   # output
# Out:
# 12

# %% [markdown]
# 20 Write a program to find the maximum value in the given list.
# Input: [99, 55, 73, 21, 64]
# Output: 99

# %%
b = [99, 55, 73, 21, 64]
__builtins__.print(max(b))    # output
# Out:
# 99

# %%
union operator

# %%
# initialize sets A B
A = {1,2,3,4,5}
B = {4,5,6,7,8}

# %%
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
 A | B
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A.intersection(B)
A & B
# Out:
# {4, 5}

# %%
A - B
# Out:
# {1, 2, 3}

# %%
B-A
# Out:
# {6, 7, 8}

# %%
A.difference(B)
A-B
# Out:
# {1, 2, 3}

# %%
A.symmetric_difference(B)
